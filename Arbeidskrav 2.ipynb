# %% [markdown]
# Arbeidskrav 2

# %%
#oppgave 1)
alder = int(input("Hvilket år er du født ? "))

print( "Du er " + str(2024-alder) + " år gammel ")
# Out:
# Hvilket år er du født ?  1998
# Du er 26 år gammel

# %%
#Oppgave 2)

antall_elever=int(input('Skriv inn antall elever: '))
pizza_pr_elev = 0.25
#pizza_total = int(antall_elever * pizza_pr_elev)#
print("Det må handles inn ", str(round(antall_elever*pizza_pr_elev)) ," pizzaer til festen")
# Out:
# Skriv inn antall elever:  21
# Det må handles inn  5  pizzaer til festen

# %%
#Oppgave 3)
import numpy as np
def grader_to_radianer():
    v_grad = float(input('skriv inn gradtallet'))
    v_rad=v_grad*np.pi/180
    print( str(v_grad) + " grader tilsvarer "+ str(vrad) + " Radianer")
grader_to_radianer()
# Out:
# skriv inn gradtallet 2
# 2.0 grader tilsvarer 0.03490658503988659 Radianer

# %%
#Oppgave 4) 

#Oppgave A)
data = {"Norge": ["Oslo", 0.634], "England": ["London ", 8.982],"Frankrike ":["Paris ", 2.161],"Italia": ["Roma ",2.873]}
#Oppgave B)
land = input ("Skriv inn land ")
hovedstad, innbyggere = data[land]
print(f"{hovedstad} er hovedstaden i {land} , Og det har {innbyggere} millioner innbyggere")
# Out:
# Skriv inn land  Norge
# Oslo er hovvedstaden i Norge , Og det har 0.634 millioner innbyggere

# %%
#Oppgave C) 

data = {"Norge": ["Oslo", 0.634], "England": ["London ", 8.982],"Frankrike ":["Paris ", 2.161],"Italia": ["Roma ",2.873]}
nytt_land = input("Skriv inn nytt land: ")
hovedstad = input("Skriv inn hovedstaden")
innbyggere = float(input("Skriv inn antall inbyggere: "))

data[nytt_land] = [hovedstad,innbyggere]
print(data)
# Out:
# Skriv inn nytt land:  denmark
# Skriv inn hovedstaden copenhage
# Skriv inn antall inbyggere:  0.99
# {'Norge': ['Oslo', 0.634], 'England': ['London ', 8.982], 'Frankrike ': ['Paris ', 2.161], 'Italia': ['Roma ', 2.873], 'denmark': ['copenhage', 0.99]}

# %%
#Oppgave 5
