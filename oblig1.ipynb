# %% [markdown]
# # Oblig 1 Regn ut Kost differansen mellom ElBil og BensinBil

# %%
import math
ForsEl = 5000
DrivEl = 0.2*2*10000 
BomEl = 0.1 * 10000
ForsBen = 7500                 
DrivBen = 1 *10000
BomBen = 0.3 * 10000
avgift = 8.38 * 365
ÅrligKostEl = forsEl + DrivEl + BomEl + avgift
ÅrligKostBen = ForsBen + DrivBen + BomBen + avgift
differansen = ÅrligKostBen - ÅrligKostEl
print (f"Årlig kostnad for elbil : {ÅrligKostEl} " )
print (f"Årlig kostnad for bensinbil: {ÅrligKostBen}")
print (f"Årlig differanse mellom bensin og elbil: {differansen}")
# Out:
# Årlig kostnad for elbil : 13058.7
# Årlig kostnad for bensinbil: 23558.7
# Årlig differanse mellom bensin og elbil: 10500.0
